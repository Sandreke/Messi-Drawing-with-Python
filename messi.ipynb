# %% [markdown]
# ### Step 1: Import [sketchpy](https://pypi.org/project/sketchpy/) library

# %%
# !pip install sketchpy

# %%
import sketchpy

# %% [markdown]
# ### Step 2: Create an object to draw Messi
# *canvas.sketch* class is used to create the object

# %%
# Create an object of canvas.sketch class
Turtle = sketchpy.canvas.sketch(x_offset=290, y_offset=320)

# %% [markdown]
# ### Step 3: Draw Messi
# It's necessary to get all coordinates of each feature. These can be obtained using [cv2](https://pypi.org/project/opencv-python/) library.

# %%
Turtle.draw_fn("Resources/background1", co=(116,172,223), mode=0)
Turtle.draw_fn("Resources/background2", co=(255, 255, 255), mode=0)
Turtle.draw_fn("Resources/background3", co=(116,172,223), mode=0)

Turtle.draw_fn("Resources/face_out", co=(233, 183, 151), mode=0)
Turtle.draw_fn("Resources/beard_out", co=(30, 25, 31), mode=0)

Turtle.draw_fn("Resources/chin1", co=(204, 139, 124), mode=0)
Turtle.draw_fn("Resources/chin2", co=(204, 139, 124), mode=0)

Turtle.draw_fn("Resources/lip_lower", co=(214, 125, 100), mode=0)
Turtle.draw_fn("Resources/lip_upper", co=(186, 30, 21), mode=0)

Turtle.draw_fn("Resources/nostril", co=(8, 15, 29), mode=0)
Turtle.draw_fn("Resources/nose_curve", co=(128, 69, 56), mode=0)
Turtle.draw_fn("Resources/right_eyebrow", co=(12, 16, 22), mode=0)
Turtle.draw_fn("Resources/left_eyebrow", co=(12, 16, 22), mode=0)

Turtle.draw_fn("Resources/noseline", co=(12, 16, 22), mode=0)

Turtle.draw_fn("Resources/eyelid", co=(13, 15, 23), mode=0)
Turtle.draw_fn("Resources/eye", co=(17, 12, 20), mode=0)
Turtle.draw_fn("Resources/sclera", co=(230, 231, 229), mode=0)
Turtle.draw_fn("Resources/eyeball", co=(15, 25, 15), mode=0)
Turtle.draw_fn("Resources/eyeball_centre", co=(230, 231, 229), mode=0)

Turtle.draw_fn("Resources/hair_outline", co=(12, 16, 25), mode=0)
Turtle.draw_fn("Resources/hair_shade1", co=(12, 16, 25), mode=0)
Turtle.draw_fn("Resources/hair_shade2", co=(61, 44, 52), mode=0)
Turtle.draw_fn("Resources/hair_shade3", co=(119, 64, 75), mode=0)
Turtle.draw_fn("Resources/hair_shade4", co=(119, 64, 75), mode=0)
Turtle.draw_fn("Resources/hair_shade5", co=(61, 44, 52), mode=0)
Turtle.draw_fn("Resources/hair_shade6", co=(119, 64, 75), mode=0)
Turtle.draw_fn("Resources/hair_shade7", co=(61, 44, 52), mode=0)
Turtle.draw_fn("Resources/hair_shade8", co=(61, 44, 52), mode=0)

Turtle.draw_fn("Resources/throat", co=(245, 207, 171), mode=0)
Turtle.draw_fn("Resources/throat_shade1", co=(236, 180, 153), mode=0)
Turtle.draw_fn("Resources/throat_shade2", co=(236, 180, 153), mode=0)

Turtle.draw_fn("Resources/ear_line1", co=(16, 10, 8), mode=0)
Turtle.draw_fn("Resources/ear_line2", co=(16, 10, 8), mode=0)
Turtle.draw_fn("Resources/ear_line3", co=(16, 10, 8), mode=0)
Turtle.draw_fn("Resources/ear_shade1", co=(212, 138, 124), mode=0)
Turtle.draw_fn("Resources/ear_shade2", co=(212, 138, 124), mode=0)
Turtle.draw_fn("Resources/ear_shade3", co=(212, 134, 122), mode=0)

Turtle.draw_fn("Resources/beard_shade1", co=(124, 77, 75), mode=0)
Turtle.draw_fn("Resources/beard_shade2", co=(127, 76, 76), mode=0)

Turtle.draw_fn("Resources/face_shade1", co=(209, 137, 122), mode=0)
Turtle.draw_fn("Resources/face_shade2", co=(208, 138, 119), mode=0)

Turtle.draw_fn("Resources/eye_shade1", co=(209, 143, 126), mode=0)
Turtle.draw_fn("Resources/eye_shade2", co=(209, 143, 126), mode=0)

Turtle.draw_fn("Resources/face_shade3", co=(245, 207, 171), mode=0)
Turtle.draw_fn("Resources/face_shade4", co=(240, 208, 169), mode=0)

Turtle.draw_fn("Resources/forhead_shade1", co=(202, 135, 119), mode=0)

Turtle.draw_fn("Resources/tshirt", co=(255, 255, 255), mode=0)
Turtle.draw_fn("Resources/tshirt_color1", co=(116,172,223), mode=0)
Turtle.draw_fn("Resources/tshirt_color2", co=(255, 255, 255), mode=0)
Turtle.draw_fn("Resources/tshirt_color3", co=(0, 0, 0), mode=0)
# Out:
# (2100, -80)
# (2100, 183)
# (-480, 183)
# (-480, 446)
# (2100, 446)
# (2100, 183)
# (-480, 709)
# (2100, 709)
# (2100, 448)
# (359, 153)
# (352, 151)
# (348, 150)
# (342, 150)
# (335, 149)
# (326, 149)
# (319, 150)
# (310, 148)
# (302, 148)
# (299, 149)
# (294, 149)
# (286, 149)
# (281, 149)
# (276, 147)
# (269, 147)
# (258, 147)
# (245, 142)
# (239, 149)
# (237, 150)
# (228, 155)
# (220, 159)
# (218, 162)
# (209, 170)
# (203, 173)
# (198, 176)
# (189, 183)
# (186, 192)
# (181, 200)
# (179, 203)
# (177, 204)
# (177, 208)
# (174, 211)
# (168, 218)
# (163, 224)
# (162, 229)
# (158, 234)
# (155, 242)
# (152, 248)
# (156, 250)
# (159, 246)
# (158, 249)
# (159, 255)
# (161, 259)
# (162, 263)
# (164, 267)
# (162, 271)
# (160, 274)
# (158, 276)
# (155, 276)
# (151, 285)
# (147, 291)
# (145, 294)
# (142, 298)
# (139, 302)
# (135, 307)
# (130, 313)
# (129, 315)
# (124, 318)
# (121, 323)
# (118, 328)
# (117, 334)
# (117, 338)
# (117, 342)
# (117, 348)
# (120, 353)
# (127, 356)
# (130, 358)
# ...
